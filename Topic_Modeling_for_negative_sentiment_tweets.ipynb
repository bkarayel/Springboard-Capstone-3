# %% [markdown]
# ## Topic Modeling of Tweets Related to Istanbul Convention
# ### Berra Karayel 0054477

# %%
# !pip install git+https://github.com/rwalk/gsdmm.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-et4s5bqo
#   Running command git clone -q https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-et4s5bqo
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gsdmm==0.1) (1.21.6)
# Building wheels for collected packages: gsdmm
#   Building wheel for gsdmm (setup.py) ... done
#   Created wheel for gsdmm: filename=gsdmm-0.1-py3-none-any.whl size=4602 sha256=e736bd74a9f9909400b7049b4d285db84661ce31371b5e4b9c8c0a46bf63236e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jzmoi9ey/wheels/34/65/a6/7eef67b88abae954fecd22587bd755c27b58a9ffe488d6b0de
# Successfully built gsdmm
# Installing collected packages: gsdmm
# Successfully installed gsdmm-0.1

# %%
import numpy as np 
import pandas as pd

from gsdmm import MovieGroupProcess

from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora, models
from gensim.utils import simple_preprocess
import gensim, spacy
from gensim.models.ldamulticore import LdaMulticore
import re


from gensim.models import Phrases
from gensim.models.phrases import Phraser

# %%
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv('/content/Negative-Sentiment-Tweets.csv', encoding='utf-8')
data.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1                       Date  \
# 0           0         36621  2022-02-19 08:50:11+00:00
# 1           4         50127  2021-03-20 09:26:24+00:00
# 2          11         10546  2021-03-20 18:55:35+00:00
# 3          37         51351  2021-03-20 04:44:45+00:00
# 4          46         19215  2021-03-20 11:05:01+00:00
# 5          54          8609  2021-03-21 09:46:14+00:00
# 6          55         23713  2021-03-20 09:39:08+00:00
# 7          59         33688  2021-03-20 05:15:40+00:00
# 8          64         42796  2021-04-06 15:34:14+00:00
# 9          73         38710  2021-09-27 07:08:03+00:00
#
#                                                Tweet            Id Sentiment
# 0  kadın cinayet baş yazmak sebep süre nafakakadı...  1.494957e+18  negative
# 1  kadın ölmek doğrusu insan ölmek zaten yasak e ...  1.373204e+18  negative
# 2  türkiye tarih i̇stanbul ant yürümek girmek son...  1.373348e+18  negative
# 3  kadın şiddet tabiî karşıyımlakın i̇stanbul söz...  1.373133e+18  negative
# 4  istanbulsöezleşmesi morardınizmi gulegülemorhalka  1.373229e+18  negative
# 5  istanbulsöezleşmesi isim ihanet proje ülke baş...  1.373572e+18  negative
# 6  kadın cinayet son yıl katmak artmışyani i̇stan...  1.373207e+18  negative
# 7  istanbulsözleşmesi cb karar iptal edilmiştebri...  1.373141e+18  negative
# 8  ömer han bey ekonomi alaka söz alt imza atmak ...  1.379457e+18  negative
# 9  doğru yanlış eleştirmek doğru yapılanlara karş...  1.442386e+18  negative

# %%
data.shape
# Out:
# (510, 6)

# %%
# create N-grams
def make_n_grams(texts):
    bigram = gensim.models.Phrases(texts, min_count=5, threshold=100)  # higher threshold fewer phrases.
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram = gensim.models.Phrases(bigram[texts], threshold=100)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    bigrams_text = [bigram_mod[doc] for doc in texts]
    trigrams_text =  [trigram_mod[bigram_mod[doc]] for doc in bigrams_text]
    return trigrams_text

# %%
data['Tweet'] = data.Tweet.values.tolist()

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence)))

# %%
tokens_tweets = list(sent_to_words(data['Tweet']))

# %% [markdown]
# GSDMM

# %% [markdown]
# Hyper-parameters of the GSDMM model:
#
# - K = 6. It is the number of clusters. We set this value after several experiments in which we started from 15 clusters. As we increased the number of clusters, the empty clusters started to appear. This was why we settled with 6 clusters.
#
# Hyperparameters; (These default parameters would work for many short texts.)
#
# - alpha =0.01 1 and beta = 0.01.
#
# - n_iters = 30.  Number of iteration.

# %%
np.random.seed(0) #for reproducability

# %%
tokens_tweets = list(sent_to_words(data["Tweet"]))

# %%
mgp = MovieGroupProcess(K=15, alpha=0.01, beta=0.01, n_iters=30) 

vocab = set(x for tweet in tokens_tweets for x in tweet)
n_terms = len(vocab)
model = mgp.fit(tokens_tweets, n_terms)
# Out:
# In stage 0: transferred 398 clusters with 15 clusters populated
# In stage 1: transferred 196 clusters with 15 clusters populated
# In stage 2: transferred 138 clusters with 15 clusters populated
# In stage 3: transferred 116 clusters with 15 clusters populated
# In stage 4: transferred 99 clusters with 15 clusters populated
# In stage 5: transferred 93 clusters with 15 clusters populated
# In stage 6: transferred 86 clusters with 15 clusters populated
# In stage 7: transferred 82 clusters with 15 clusters populated
# In stage 8: transferred 79 clusters with 15 clusters populated
# In stage 9: transferred 86 clusters with 15 clusters populated
# In stage 10: transferred 76 clusters with 15 clusters populated
# In stage 11: transferred 79 clusters with 15 clusters populated
# In stage 12: transferred 71 clusters with 15 clusters populated
# In stage 13: transferred 75 clusters with 15 clusters populated
# In stage 14: transferred 75 clusters with 15 clusters populated
# In stage 15: transferred 77 clusters with 15 clusters populated
# In stage 16: transferred 84 clusters with 15 clusters populated
# In stage 17: transferred 80 clusters with 15 clusters populated
# In stage 18: transferred 82 clusters with 15 clusters populated
# In stage 19: transferred 69 clusters with 15 clusters populated
# In stage 20: transferred 80 clusters with 15 clusters populated
# In stage 21: transferred 76 clusters with 15 clusters populated
# In stage 22: transferred 79 clusters with 15 clusters populated
# In stage 23: transferred 68 clusters with 15 clusters populated
# In stage 24: transferred 65 clusters with 15 clusters populated
# In stage 25: transferred 75 clusters with 15 clusters populated
# In stage 26: transferred 73 clusters with 15 clusters populated
# In stage 27: transferred 61 clusters with 15 clusters populated
# In stage 28: transferred 80 clusters with 15 clusters populated
# In stage 29: transferred 73 clusters with 15 clusters populated

# %%
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts =sorted(mgp.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster,sort_dicts))

# %%
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic :', doc_count)

# topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-15:][::-1]
print('\nMost important clusters (by number of docs inside):', top_index)
# show the top 5 words in term frequency for each cluster 
top_words(mgp.cluster_word_distribution, top_index, 20)
# Out:
# Number of documents per topic : [18 32 14 36 25 35 37 14 26 29 91 70 24 34 25]
#
# Most important clusters (by number of docs inside): [10 11  6  3  5 13  1  9  8 14  4 12  0  7  2]
#
# Cluster 10 : [('sözleşme', 80), ('stanbul', 58), ('bir', 33), ('olmak', 33), ('kadın', 29), ('hal', 12), ('demek', 12), ('biz', 11), ('desen', 11), ('var', 10), ('vermek', 10), ('iyi', 9), ('slâm', 9), ('kalmak', 9), ('avrupa', 8), ('devlet', 8), ('mi', 8), ('iş', 8), ('yok', 8), ('cinayet', 8)]
#
# Cluster 11 : [('sözleşme', 61), ('kadın', 59), ('stanbul', 52), ('bir', 24), ('olmak', 24), ('var', 20), ('korumak', 19), ('tecavüz', 14), ('mi', 14), ('bu', 13), ('şiddet', 13), ('ülke', 12), ('demek', 12), ('cinayet', 11), ('taciz', 11), ('yok', 9), ('değmek', 9), ('desen', 9), ('kadar', 9), ('hak', 8)]
#
# Cluster 6 : [('sözleşme', 31), ('stanbul', 26), ('kadın', 16), ('chp', 16), ('bir', 10), ('tecavüz', 10), ('taciz', 8), ('iç', 7), ('korumak', 6), ('made', 6), ('nin', 6), ('olmak', 5), ('demek', 5), ('desen', 5), ('mi', 4), ('çıkarmak', 4), ('sıra', 4), ('etmek', 4), ('önem', 4), ('gelmek', 4)]
#
# Cluster 3 : [('sözleşme', 39), ('stanbul', 32), ('kadın', 17), ('ölmek', 14), ('değmek', 13), ('olmak', 13), ('yaşamak', 12), ('slâm', 10), ('bir', 9), ('zaten', 8), ('var', 7), ('istemek', 7), ('insan', 7), ('bu', 6), ('iş', 6), ('ada', 6), ('mu', 6), ('desen', 6), ('allah', 5), ('cinayet', 5)]
#
# Cluster 5 : [('sözleşme', 27), ('stanbul', 23), ('kadın', 21), ('bir', 11), ('cinayet', 11), ('yaşamak', 10), ('demek', 8), ('kalmak', 7), ('yıl', 7), ('almak', 6), ('artmak', 6), ('katmak', 6), ('sonra', 6), ('şükür', 6), ('olmak', 5), ('iş', 5), ('imza', 5), ('şiddet', 5), ('etmek', 4), ('iptal', 4)]
#
# Cluster 13 : [('sözleşme', 19), ('stanbul', 13), ('olmak', 11), ('bir', 10), ('aile', 10), ('yapı', 8), ('çöp', 7), ('fatih', 7), ('ahlak', 7), ('millet', 6), ('var', 6), ('erbakan', 6), ('türk', 6), ('artık', 6), ('şükür', 6), ('önce', 5), ('lider', 5), ('atmak', 4), ('ayasofya', 4), ('şimdi', 4)]
#
# Cluster 1 : [('sözleşme', 41), ('kadın', 29), ('stanbul', 27), ('bir', 20), ('yaşamak', 18), ('mi', 12), ('demek', 11), ('insan', 10), ('ölmek', 9), ('var', 9), ('yok', 7), ('atmak', 6), ('slâm', 6), ('se', 5), ('böyle', 5), ('bu', 5), ('şiddet', 5), ('ben', 5), ('size', 5), ('allah', 5)]
#
# Cluster 9 : [('bir', 16), ('sözleşme', 12), ('aile', 11), ('olmak', 10), ('stanbul', 8), ('erkek', 8), ('elhamdülillah', 8), ('kadın', 5), ('ede', 5), ('müslüman', 5), ('feshetmek', 5), ('nesil', 4), ('ifade', 4), ('bitmek', 4), ('ge', 4), ('kadar', 3), ('yıkanmak', 3), ('söz', 3), ('türk', 3), ('belâ', 3)]
#
# Cluster 8 : [('sözleşme', 24), ('bir', 21), ('stanbul', 13), ('toplum', 13), ('yapı', 8), ('bu', 7), ('olmak', 6), ('lgbt', 6), ('aile', 6), ('kadın', 6), ('değmek', 6), ('yi', 5), ('kendi', 5), ('var', 5), ('ad', 5), ('yaşamak', 4), ('güzel', 4), ('allah', 4), ('alt', 4), ('cinsiyet', 4)]
#
# Cluster 14 : [('sözleşme', 18), ('kadın', 13), ('stanbul', 10), ('mi', 7), ('alt', 6), ('sağlamak', 5), ('korumak', 5), ('kanu', 4), ('bir', 4), ('teşekkür', 4), ('fesih', 4), ('sapkın', 4), ('koru', 4), ('hak', 3), ('taraf', 3), ('yanlış', 3), ('düzenlemek', 3), ('eder', 3), ('hoca', 3), ('imek', 3)]
#
# Cluster 4 : [('sözleşme', 25), ('stanbul', 24), ('kadın', 9), ('bir', 8), ('iptal', 7), ('imza', 6), ('çocuk', 6), ('desen', 5), ('değişmek', 5), ('yanlış', 5), ('kalmak', 5), ('vermek', 4), ('olmak', 4), ('etmek', 4), ('ölmek', 4), ('kanu', 4), ('korumak', 4), ('türk', 3), ('hal', 3), ('iyi', 3)]
#
# Cluster 12 : [('sözleşme', 27), ('stanbul', 19), ('bir', 12), ('yok', 9), ('olmak', 9), ('kendi', 8), ('kadın', 7), ('ülke', 7), ('kabul', 7), ('şey', 6), ('desen', 6), ('etmek', 6), ('istemek', 5), ('allah', 5), ('mi', 5), ('bu', 4), ('uygu', 4), ('ben', 4), ('yapmak', 4), ('se', 4)]
#
# Cluster 0 : [('sözleşme', 15), ('stanbul', 11), ('kadın', 9), ('bir', 9), ('demek', 7), ('size', 6), ('allah', 6), ('madde', 5), ('aile', 4), ('se', 4), ('deva', 4), ('çocuk', 4), ('var', 4), ('durmak', 4), ('etmek', 3), ('uygulamak', 3), ('ne', 3), ('gerekmek', 3), ('ileri', 3), ('millet', 3)]
#
# Cluster 7 : [('kadın', 9), ('sözleşme', 8), ('stanbul', 6), ('şiddet', 5), ('iptal', 5), ('cinayet', 4), ('ooohhh', 4), ('gün', 3), ('millet', 3), ('olmak', 3), ('imzalamak', 3), ('siz', 3), ('dayamak', 3), ('eşcinsel', 3), ('gi', 3), ('ni', 3), ('eşit', 3), ('bu', 2), ('ediyor', 2), ('ülke', 2)]
#
# Cluster 2 : [('sözleşme', 13), ('stanbul', 11), ('olmak', 8), ('bir', 7), ('parti', 6), ('kadın', 5), ('taraf', 5), ('demek', 4), ('bu', 4), ('var', 4), ('değmek', 4), ('lgbt', 4), ('ak', 4), ('konuşmak', 3), ('ayrıç', 3), ('sosyal', 3), ('erkek', 3), ('tam', 3), ('adalet', 3), ('iş', 2)]

# %%
gsdmm_clusters = [

["Cluster 10 : [('sözleşme', 80), ('stanbul', 58), ('bir', 33), ('olmak', 33), ('kadın', 29), ('hal', 12), ('demek', 12), ('biz', 11), ('desen', 11), ('var', 10), ('vermek', 10), ('iyi', 9), ('slâm', 9), ('kalmak', 9), ('avrupa', 8), ('devlet', 8), ('mi', 8), ('iş', 8), ('yok', 8), ('cinayet', 8)"],

["Cluster 11 : [('sözleşme', 61), ('kadın', 59), ('stanbul', 52), ('bir', 24), ('olmak', 24), ('var', 20), ('korumak', 19), ('tecavüz', 14), ('mi', 14), ('bu', 13), ('şiddet', 13), ('ülke', 12), ('demek', 12), ('cinayet', 11), ('taciz', 11), ('yok', 9), ('değmek', 9), ('desen', 9), ('kadar', 9), ('hak', 8)"],

["Cluster 6 : [('sözleşme', 31), ('stanbul', 26), ('kadın', 16), ('chp', 16), ('bir', 10), ('tecavüz', 10), ('taciz', 8), ('iç', 7), ('korumak', 6), ('made', 6), ('nin', 6), ('olmak', 5), ('demek', 5), ('desen', 5), ('mi', 4), ('çıkarmak', 4), ('sıra', 4), ('etmek', 4), ('önem', 4), ('gelmek', 4)"],

["Cluster 3 : [('sözleşme', 39), ('stanbul', 32), ('kadın', 17), ('ölmek', 14), ('değmek', 13), ('olmak', 13), ('yaşamak', 12), ('slâm', 10), ('bir', 9), ('zaten', 8), ('var', 7), ('istemek', 7), ('insan', 7), ('bu', 6), ('iş', 6), ('ada', 6), ('mu', 6), ('desen', 6), ('allah', 5), ('cinayet', 5)"],

["Cluster 5 : [('sözleşme', 27), ('stanbul', 23), ('kadın', 21), ('bir', 11), ('cinayet', 11), ('yaşamak', 10), ('demek', 8), ('kalmak', 7), ('yıl', 7), ('almak', 6), ('artmak', 6), ('katmak', 6), ('sonra', 6), ('şükür', 6), ('olmak', 5), ('iş', 5), ('imza', 5), ('şiddet', 5), ('etmek', 4), ('iptal', 4)"],

["Cluster 13 : [('sözleşme', 19), ('stanbul', 13), ('olmak', 11), ('bir', 10), ('aile', 10), ('yapı', 8), ('çöp', 7), ('fatih', 7), ('ahlak', 7), ('millet', 6), ('var', 6), ('erbakan', 6), ('türk', 6), ('artık', 6), ('şükür', 6), ('önce', 5), ('lider', 5), ('atmak', 4), ('ayasofya', 4), ('şimdi', 4)"],

["Cluster 1 : [('sözleşme', 41), ('kadın', 29), ('stanbul', 27), ('bir', 20), ('yaşamak', 18), ('mi', 12), ('demek', 11), ('insan', 10), ('ölmek', 9), ('var', 9), ('yok', 7), ('atmak', 6), ('slâm', 6), ('se', 5), ('böyle', 5), ('bu', 5), ('şiddet', 5), ('ben', 5), ('size', 5), ('allah', 5)"],

["Cluster 9 : [('bir', 16), ('sözleşme', 12), ('aile', 11), ('olmak', 10), ('stanbul', 8), ('erkek', 8), ('elhamdülillah', 8), ('kadın', 5), ('ede', 5), ('müslüman', 5), ('feshetmek', 5), ('nesil', 4), ('ifade', 4), ('bitmek', 4), ('ge', 4), ('kadar', 3), ('yıkanmak', 3), ('söz', 3), ('türk', 3), ('belâ', 3)"],

["Cluster 8 : [('sözleşme', 24), ('bir', 21), ('stanbul', 13), ('toplum', 13), ('yapı', 8), ('bu', 7), ('olmak', 6), ('lgbt', 6), ('aile', 6), ('kadın', 6), ('değmek', 6), ('yi', 5), ('kendi', 5), ('var', 5), ('ad', 5), ('yaşamak', 4), ('güzel', 4), ('allah', 4), ('alt', 4), ('cinsiyet', 4)"],

["Cluster 14 : [('sözleşme', 18), ('kadın', 13), ('stanbul', 10), ('mi', 7), ('alt', 6), ('sağlamak', 5), ('korumak', 5), ('kanu', 4), ('bir', 4), ('teşekkür', 4), ('fesih', 4), ('sapkın', 4), ('koru', 4), ('hak', 3), ('taraf', 3), ('yanlış', 3), ('düzenlemek', 3), ('eder', 3), ('hoca', 3), ('imek', 3)"],

["Cluster 4 : [('sözleşme', 25), ('stanbul', 24), ('kadın', 9), ('bir', 8), ('iptal', 7), ('imza', 6), ('çocuk', 6), ('desen', 5), ('değişmek', 5), ('yanlış', 5), ('kalmak', 5), ('vermek', 4), ('olmak', 4), ('etmek', 4), ('ölmek', 4), ('kanu', 4), ('korumak', 4), ('türk', 3), ('hal', 3), ('iyi', 3)"],

["Cluster 12 : [('sözleşme', 27), ('stanbul', 19), ('bir', 12), ('yok', 9), ('olmak', 9), ('kendi', 8), ('kadın', 7), ('ülke', 7), ('kabul', 7), ('şey', 6), ('desen', 6), ('etmek', 6), ('istemek', 5), ('allah', 5), ('mi', 5), ('bu', 4), ('uygu', 4), ('ben', 4), ('yapmak', 4), ('se', 4)"],

["Cluster 0 : [('sözleşme', 15), ('stanbul', 11), ('kadın', 9), ('bir', 9), ('demek', 7), ('size', 6), ('allah', 6), ('madde', 5), ('aile', 4), ('se', 4), ('deva', 4), ('çocuk', 4), ('var', 4), ('durmak', 4), ('etmek', 3), ('uygulamak', 3), ('ne', 3), ('gerekmek', 3), ('ileri', 3), ('millet', 3)"],

["Cluster 7 : [('kadın', 9), ('sözleşme', 8), ('stanbul', 6), ('şiddet', 5), ('iptal', 5), ('cinayet', 4), ('ooohhh', 4), ('gün', 3), ('millet', 3), ('olmak', 3), ('imzalamak', 3), ('siz', 3), ('dayamak', 3), ('eşcinsel', 3), ('gi', 3), ('ni', 3), ('eşit', 3), ('bu', 2), ('ediyor', 2), ('ülke', 2)"],

["Cluster 2 : [('sözleşme', 13), ('stanbul', 11), ('olmak', 8), ('bir', 7), ('parti', 6), ('kadın', 5), ('taraf', 5), ('demek', 4), ('bu', 4), ('var', 4), ('değmek', 4), ('lgbt', 4), ('ak', 4), ('konuşmak', 3), ('ayrıç', 3), ('sosyal', 3), ('erkek', 3), ('tam', 3), ('adalet', 3), ('iş', 2)"]]

# %%
gsdmm_clusters = pd.DataFrame.from_dict(gsdmm_clusters)

# %%
gsdmm_clusters
# Out:
#                                                     0
# 0   Cluster 10 : [('sözleşme', 80), ('stanbul', 58...
# 1   Cluster 11 : [('sözleşme', 61), ('kadın', 59),...
# 2   Cluster 6 : [('sözleşme', 31), ('stanbul', 26)...
# 3   Cluster 3 : [('sözleşme', 39), ('stanbul', 32)...
# 4   Cluster 5 : [('sözleşme', 27), ('stanbul', 23)...
# 5   Cluster 13 : [('sözleşme', 19), ('stanbul', 13...
# 6   Cluster 1 : [('sözleşme', 41), ('kadın', 29), ...
# 7   Cluster 9 : [('bir', 16), ('sözleşme', 12), ('...
# 8   Cluster 8 : [('sözleşme', 24), ('bir', 21), ('...
# 9   Cluster 14 : [('sözleşme', 18), ('kadın', 13),...
# 10  Cluster 4 : [('sözleşme', 25), ('stanbul', 24)...
# 11  Cluster 12 : [('sözleşme', 27), ('stanbul', 19...
# 12  Cluster 0 : [('sözleşme', 15), ('stanbul', 11)...
# 13  Cluster 7 : [('kadın', 9), ('sözleşme', 8), ('...
# 14  Cluster 2 : [('sözleşme', 13), ('stanbul', 11)...

# %%
gsdmm_clusters.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
gsdmm_clusters.rename(columns={0: "Dominant Keywords for GSDMM Clusters"}, inplace=True)

# %%
type(gsdmm_clusters)
# Out:
# pandas.core.frame.DataFrame

# %%
gsdmm_clusters.columns
# Out:
# Index(['Dominant Keywords for GSDMM Clusters'], dtype='object')

# %%
gsdmm_clusters[['Cluster No.(Importance)','Dominant Keywords:GSDMM']] = gsdmm_clusters["Dominant Keywords for GSDMM Clusters"].str.split(":",expand=True,)
gsdmm_clusters
# Out:
#                  Dominant Keywords for GSDMM Clusters Cluster No.(Importance)  \
# 0   Cluster 10 : [('sözleşme', 80), ('stanbul', 58...             Cluster 10
# 1   Cluster 11 : [('sözleşme', 61), ('kadın', 59),...             Cluster 11
# 2   Cluster 6 : [('sözleşme', 31), ('stanbul', 26)...              Cluster 6
# 3   Cluster 3 : [('sözleşme', 39), ('stanbul', 32)...              Cluster 3
# 4   Cluster 5 : [('sözleşme', 27), ('stanbul', 23)...              Cluster 5
# 5   Cluster 13 : [('sözleşme', 19), ('stanbul', 13...             Cluster 13
# 6   Cluster 1 : [('sözleşme', 41), ('kadın', 29), ...              Cluster 1
# 7   Cluster 9 : [('bir', 16), ('sözleşme', 12), ('...              Cluster 9
# 8   Cluster 8 : [('sözleşme', 24), ('bir', 21), ('...              Cluster 8
# 9   Cluster 14 : [('sözleşme', 18), ('kadın', 13),...             Cluster 14
# 10  Cluster 4 : [('sözleşme', 25), ('stanbul', 24)...              Cluster 4
# 11  Cluster 12 : [('sözleşme', 27), ('stanbul', 19...             Cluster 12
# 12  Cluster 0 : [('sözleşme', 15), ('stanbul', 11)...              Cluster 0
# 13  Cluster 7 : [('kadın', 9), ('sözleşme', 8), ('...              Cluster 7
# 14  Cluster 2 : [('sözleşme', 13), ('stanbul', 11)...              Cluster 2
#
#                               Dominant Keywords:GSDMM
# 0    [('sözleşme', 80), ('stanbul', 58), ('bir', 3...
# 1    [('sözleşme', 61), ('kadın', 59), ('stanbul',...
# 2    [('sözleşme', 31), ('stanbul', 26), ('kadın',...
# 3    [('sözleşme', 39), ('stanbul', 32), ('kadın',...
# 4    [('sözleşme', 27), ('stanbul', 23), ('kadın',...
# 5    [('sözleşme', 19), ('stanbul', 13), ('olmak',...
# 6    [('sözleşme', 41), ('kadın', 29), ('stanbul',...
# 7    [('bir', 16), ('sözleşme', 12), ('aile', 11),...
# 8    [('sözleşme', 24), ('bir', 21), ('stanbul', 1...
# 9    [('sözleşme', 18), ('kadın', 13), ('stanbul',...
# 10   [('sözleşme', 25), ('stanbul', 24), ('kadın',...
# 11   [('sözleşme', 27), ('stanbul', 19), ('bir', 1...
# 12   [('sözleşme', 15), ('stanbul', 11), ('kadın',...
# 13   [('kadın', 9), ('sözleşme', 8), ('stanbul', 6...
# 14   [('sözleşme', 13), ('stanbul', 11), ('olmak',...

# %%
# I didn`t rename the clusters

topic_dict = {}
topic_names = ['type 1',
               'type 2',
               'type 3',
               'type 4',
               'type 5',
               'type 6',
               'type 7',
               'type 8',
               'type 9',
               'type 10',
               'type 11',
               'type 12',
               'type 13',
               'type 14',
               'type 15'
              ]
for i, topic_num in enumerate(top_index):
    topic_dict[topic_num]=topic_names[i]

# %%
def create_topics_dataframe(data_text=data.Tweet,  mgp=mgp, threshold=0.3, topic_dict=topic_dict, lemma_text=tokens_tweets):
    result = pd.DataFrame(columns=['Text', 'Topic', 'Rating', 'Lemma-text'])
    for i, text in enumerate(data_text):
        result.at[i, 'Text'] = text
        #result.at[i, 'Rating'] = data.Rating[i]
        result.at[i, 'Lemma-text'] = lemma_text[i]
        prob = mgp.choose_best_label(tokens_tweets[i])
        if prob[1] >= threshold:
            result.at[i, 'Topic'] = topic_dict[prob[0]]
        else:
            result.at[i, 'Topic'] = 'Other'
    return result

# %%
result = create_topics_dataframe(data_text=data.Tweet, mgp=mgp, threshold=0.3, topic_dict=topic_dict, lemma_text=tokens_tweets)
result.head(5)
# Out:
#                                                 Text   Topic Rating  \
# 0  kadın cinayet baş yazmak sebep süre nafakakadı...  type 9    NaN
# 1  kadın ölmek doğrusu insan ölmek zaten yasak e ...  type 4    NaN
# 2  türkiye tarih i̇stanbul ant yürümek girmek son...  type 5    NaN
# 3  kadın şiddet tabiî karşıyımlakın i̇stanbul söz...  type 2    NaN
# 4  istanbulsöezleşmesi morardınizmi gulegülemorhalka   Other    NaN
#
#                                           Lemma-text
# 0  [kadın, cinayet, baş, yazmak, sebep, süre, naf...
# 1  [kadın, ölmek, doğrusu, insan, ölmek, zaten, y...
# 2  [türkiye, tarih, stanbul, ant, yürümek, girmek...
# 3  [kadın, şiddet, tabiî, karşıyımlakın, stanbul,...
# 4                                     [morardınizmi]

# %% [markdown]
# # Visualization for the GSDM model

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
import plotly.express as px

fig = px.pie(result, names='Topic',  title="Figure 3. GSDMM for Tweets with Negative Sentiment", color_discrete_sequence=px.colors.sequential.Burg)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="88c4f98f-6ab0-431e-8a9e-8da829a44870" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88c4f98f-6ab0-431e-8a9e-8da829a44870")) {                    Plotly.newPlot(                        "88c4f98f-6ab0-431e-8a9e-8da829a44870",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Topic=%{label}<extra></extra>","labels":["type 9","type 4","type 5","type 2","Other","type 1","type 5","type 1","type 2","type 1","type 7","type 6","type 8","type 1","Other","Other","type 12","type 7","type 1","type 8","type 9","type 11","type 1","type 12","type 15","type 4","type 1","type 11","type 6","type 7","type 2","type 12","type 4","type 5","type 1","type 4","type 1","type 13","type 2","type 1","type 1","type 1","type 2","type 11","type 1","type 12","type 9","type 3","type 7","type 1","type 13","type 1","type 7","type 1","type 5","type 2","type 3","type 5","type 1","type 3","type 2","type 4","type 2","type 9","Other","type 5","type 1","type 2","type 1","type 2","type 2","type 2","type 1","type 1","type 4","type 2","type 1","type 8","type 4","type 11","type 4","type 8","type 3","type 5","type 5","type 5","type 6","type 4","type 7","type 2","type 6","type 9","type 2","type 2","type 3","type 1","type 8","type 2","type 9","type 9","type 6","type 2","type 6","type 11","type 13","type 8","type 9","type 1","type 7","type 1","type 1","type 2","type 10","type 1","type 11","type 2","type 10","type 7","type 4","type 15","type 1","type 6","type 8","type 7","type 1","type 10","type 2","type 6","type 2","type 12","type 2","type 7","type 9","type 11","type 14","Other","type 10","type 12","type 1","type 4","type 9","type 15","type 6","type 10","type 2","type 9","type 2","type 11","type 9","type 10","type 15","type 2","type 1","type 10","type 1","type 8","type 8","type 7","type 5","type 10","type 1","type 14","type 5","type 6","type 10","type 12","type 2","type 11","type 4","type 3","type 4","type 3","type 9","type 10","type 10","type 2","type 12","type 4","type 3","Other","type 7","type 3","type 1","type 1","type 14","type 5","type 2","type 7","Other","type 5","type 9","type 5","type 8","type 12","Other","type 12","type 3","type 1","type 10","type 7","type 11","type 4","type 10","type 1","type 5","type 13","type 8","type 9","type 3","type 3","type 5","type 12","type 8","type 5","type 11","type 2","type 6","type 6","type 4","type 13","type 4","type 3","type 5","type 4","type 6","type 7","type 1","type 2","type 10","type 2","type 3","type 2","type 6","type 15","type 1","type 4","Other","type 9","type 9","type 1","type 1","type 10","Other","type 6","type 7","type 4","type 1","type 4","type 15","type 5","type 2","type 11","type 7","type 2","type 8","type 3","type 1","type 4","type 2","type 8","type 10","type 1","type 2","type 1","type 12","type 9","Other","type 12","type 8","type 2","type 7","type 2","type 6","type 3","type 6","type 1","type 10","type 2","type 1","type 1","type 12","type 14","type 2","type 9","type 4","type 1","type 1","type 8","type 9","type 2","type 6","Other","type 11","type 12","type 5","type 13","type 13","type 4","type 2","type 10","type 1","type 6","type 11","type 1","Other","type 11","type 1","type 9","type 3","type 2","type 2","type 13","type 1","type 4","type 12","type 7","type 11","type 1","type 2","type 2","type 4","type 2","type 15","type 1","type 11","type 5","type 7","type 11","type 10","type 1","type 12","type 1","type 4","type 3","type 1","type 8","type 6","type 6","type 5","type 15","type 8","type 1","type 6","type 2","type 5","type 13","type 14","type 1","type 15","type 1","type 8","type 3","type 3","type 6","type 5","type 11","type 2","type 5","type 2","type 15","type 7","type 10","type 9","type 6","type 13","t ...

# %%
result['len'] = result.Text.apply(lambda row: len(row.split()))
result.head()
# Out:
#                                                 Text   Topic Rating  \
# 0  kadın cinayet baş yazmak sebep süre nafakakadı...  type 9    NaN
# 1  kadın ölmek doğrusu insan ölmek zaten yasak e ...  type 4    NaN
# 2  türkiye tarih i̇stanbul ant yürümek girmek son...  type 5    NaN
# 3  kadın şiddet tabiî karşıyımlakın i̇stanbul söz...  type 2    NaN
# 4  istanbulsöezleşmesi morardınizmi gulegülemorhalka   Other    NaN
#
#                                           Lemma-text  len
# 0  [kadın, cinayet, baş, yazmak, sebep, süre, naf...   22
# 1  [kadın, ölmek, doğrusu, insan, ölmek, zaten, y...   36
# 2  [türkiye, tarih, stanbul, ant, yürümek, girmek...   26
# 3  [kadın, şiddet, tabiî, karşıyımlakın, stanbul,...   16
# 4                                     [morardınizmi]    3

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## WordClouds

# %%
result['Lemma_text'] = result['Lemma-text'].apply(lambda row: ' '.join(row))

# %%
result = result.drop('Lemma-text', axis=1)

# %%
from wordcloud import WordCloud

# %%
my_stopwords = ["istanbul", "stanbul", "sözleşme", "böyle", "bir", "bu", "şey", "mi", "mı", "var", "tamam"]

# %%
def create_WordCloud(data, title=None):
    wordcloud = WordCloud(width = 500, height = 500,
                          background_color ='white',
                          min_font_size = 15, stopwords = my_stopwords
                         ).generate(" ".join(data.values))
                      
    plt.figure(figsize = (5, 5), facecolor = None) 
    plt.imshow(wordcloud, interpolation='bilinear') 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title(title,fontsize=20)
    plt.show()

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 1'], title="Most used words in negative sentiment tweets" )

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 2'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 3'], title="Most used words in topic 3")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 4'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 5'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 6'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 7'], title="Most used words in topic 7")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 8'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 8'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 9'], title="Most used words in topic 9")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 10'], title="Most used words in topic 10")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 11'], title="Most used words in topic 11")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 12'], title="Most used words in topic 12")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 13'], title="Most used words in topic 13")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 14'], title="Most used words in negative sentiment tweets")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'type 15'], title="Most used words in topic 15")

# %%
create_WordCloud(result['Lemma_text'].loc[result.Topic == 'Other'], title="Most used words in Other")
